# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
sys.path.append(os.path.abspath('../..'))
from entropy.datamanip import *
from entropy.plotter import *
from entropy.regression import *
from entropy.measureError import *
from entropy.regressionC import *
print("Import success")
# Out:
# Import success

# %%
dfLinear = pd.read_csv('../../data/linear.csv')

X = dfLinear['ps']
Y = dfLinear['fs']

print(dfLinear)
# Out:
#     ps  fs
# 0   90  93
# 1   87  88
# 2  100  98
# 3   78  78
# 4   75  76
# 5   74  76
# 6   70  69
# 7   50  60
# 8   20  10
# 9   12  10

# %%
X = dfLinear['ps'].values.reshape(-1, 1).astype('float64')
Y = dfLinear['fs'].values.reshape(-1, 1).astype('float64')

print("Reshaping Success")
# Out:
# Reshaping Success

# %%
model = LinearRegression()
model.train(x=X, y=Y, epoch=30000, lr=0.0001)

inp = np.array([90.0])
ypred = model.predict(inp)

print(f"Input: {inp}\nPredict: {ypred}")
# Out:
# Input: [90.]
# Predict: [91.3920886]

# %%
ypred = model.predict(np.array([78], dtype='float64'))
print(ypred)
# Out:
# [78.91564265]
